# %% [markdown]
# # Comments and Errors
# ## Practice Problems

# %% [markdown]
# ### 1. Which of these expressions results in an error? Why does each error occur?

# %%
((((5 * 4 ** 7)))) #Sytax is correct, no error will be raised
# Out:
# 81920

# %% [markdown]
# <details>
#   <summary>Answer</summary>
#
#   Valid -- Python accepts extraneous parentheses.
# </details>

# %%
84 *= 0.5 / 7 # This line will raise a SyntaxError because you cannot assign a value to an integer literal
# Out:
#   Cell In[8], line 1
#     84 *= 0.5 / 7 # This line will raise a SyntaxError because you cannot assign a value to an integer literal
#     ^
# SyntaxError: 'literal' is an illegal expression for augmented assignment

# %% [markdown]
# <details>
#   <summary>Answer</summary>
#
#   Error -- Python thinks we are trying to assign a value to 84, which is an integer literal. We can't change its value!
# </details>

# %%
(-(-(-(-5 * (4 + 3))))) # Syntax is correct, no error will be raised
# Out:
# 35

# %% [markdown]
# <details>
#   <summary>Answer</summary>
#
#   Answer: Valid -- The `-` negates the value in the parentheses.
# </details>

# %%
5 * 3 = weight #Cannot assign a value to an expression, this will raise a SyntaxError
# Out:
#   Cell In[11], line 1
#     5 * 3 = weight #
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %% [markdown]
# <details>
#   <summary>Answer</summary>
#
#   Error -- We cannot assign a value to an expression, even if `weight` had been defined.
# </details>

# %%
73 / -----------5 # Syntax is correct, no error will be raised
# Out:
# -14.6

# %% [markdown]
# <details>
#   <summary>Answer</summary>
#
#   Valid -- negatives cancel each other out.
# </details>

# %% [markdown]
# ### 2. Write a block of code to check if the value is a string. If it is, print out a message saying it is valid. Otherwise, raise an exception with a message saying the value must be a string.

# %%
value = 6
#value = "Hello, World!" # Comment the above line to test with a string


if isinstance(value, str):
    print("The value is a valid string.")
else:
    raise Exception("The value must be a string.")
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[23], line 8
#       6     print("The value is a valid string.")
#       7 else:
# ----> 8     raise Exception("The value must be a string.")
#
# Exception: The value must be a string.

# %% [markdown]
# <details>
#   <summary>Answer</summary>
#
#   ```python
#   value = 6
#
#   if type(value) == str:
#     print("It is valid!")
#   else:
#     raise TypeError("The value must be a string!")
#   ```
# </details>

# %% [markdown]
# ### 3. What are the following errors?
#
# ```python
# arr = [1, 2, 3]
# print(arr[3])
# ```
#
# <details>
#   <summary>Answer</summary>
#
#   IndexError
# </details>

# %%
arr = [1, 2, 3]
print(arr[3])   # This will raise an IndexError because the index 3 is out of range for the list with 3 elements (0, 1, 2).
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 2
#       1 arr = [1, 2, 3]
# ----> 2 print(arr[3])   # This will raise an IndexError because the index 3 is out of range for the list with 3 elements (0, 1, 2).
#
# IndexError: list index out of range

# %% [markdown]
# ```python
# fullName = "Taylor Swift"
# print(full_name)
# ```
#
# <details>
#   <summary>Answer</summary>
#
#   NameError
# </details>

# %%
fullName = "Taylor Swift"
print(full_Name)  # This will raise a NameError because full_Name is not defined, it should be fullName.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 2
#       1 fullName = "Taylor Swift"
# ----> 2 print(full_Name)  # This will print the full name as a string.
#
# NameError: name 'full_Name' is not defined

# %% [markdown]
# ```python
# 2 + '2' + 4
# ```
#
# <details>
#   <summary>Answer</summary>
#
#   TypeError
# </details>

# %%
2 + '2' + 4 # This will raise a TypeError because you cannot concatenate a string and an integer directly.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 2 + '2' + 4 # This will raise a TypeError because you cannot concatenate a string and an integer directly.
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'
